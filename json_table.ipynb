# %%
import pandas as pd

# %%
df = pd.read_csv('./data/links.csv')

# %%
df.head()
# Out:
#                                                Links  \
# 0  https://catalog.data.gov/dataset/?tags=dispute...
# 1  https://catalog.data.gov/dataset?q=Civic+engag...
# 2  https://catalog.data.gov/dataset?q=Civilian+po...
# 3  https://catalog.data.gov/dataset?q=Conflict-fo...
# 4  https://catalog.data.gov/dataset?q=Civil+socie...
#
#                                      Tags       Type
# 0                      Dispute Resolution  Open Data
# 1            Civic engagement initiatives  Open Data
# 2                  Civilian police reform  Open Data
# 3  Conflict-focused early warning systems  Open Data
# 4         Civil society capacity building  Open Data

# %%
df = df[~df['Type'].isnull()]
df.head()
# Out:
#                                                Links  \
# 0  https://catalog.data.gov/dataset/?tags=dispute...
# 1  https://catalog.data.gov/dataset?q=Civic+engag...
# 2  https://catalog.data.gov/dataset?q=Civilian+po...
# 3  https://catalog.data.gov/dataset?q=Conflict-fo...
# 4  https://catalog.data.gov/dataset?q=Civil+socie...
#
#                                      Tags       Type
# 0                      Dispute Resolution  Open Data
# 1            Civic engagement initiatives  Open Data
# 2                  Civilian police reform  Open Data
# 3  Conflict-focused early warning systems  Open Data
# 4         Civil society capacity building  Open Data

# %%
df['Links'] = df.groupby('Tags')['Links'].apply(list).reset_index(name='Links')['Links']
df.head()
# Out:
#                                                Links  \
# 0  [https://catalog.data.gov/dataset?q=Civic+enga...
# 1  [https://catalog.data.gov/dataset/?tags=capaci...
# 2  [https://catalog.data.gov/dataset?q=Civil+soci...
# 3  [https://catalog.data.gov/dataset?q=Civilian+p...
# 4  [https://catalog.data.gov/dataset/?tags=improv...
#
#                                      Tags       Type
# 0                      Dispute Resolution  Open Data
# 1            Civic engagement initiatives  Open Data
# 2                  Civilian police reform  Open Data
# 3  Conflict-focused early warning systems  Open Data
# 4         Civil society capacity building  Open Data

# %%
import json

# Define a custom function to create a nested structure
def custom_nested_structure(row):
    return {row['Tags']: {'Links': row['Links'], 'Type': row['Type']}}

# Apply the custom function to each row of the DataFrame
json_data_custom = df.apply(custom_nested_structure, axis=1).tolist()

# Convert list of dictionaries to JSON
json_output = json.dumps(json_data_custom, indent=4)

with open("./data/links.json", "w") as file:
    file.write(json_output)
